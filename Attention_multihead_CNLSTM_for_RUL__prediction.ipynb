# %% [markdown]
# # Attention-based multihead convolution long-short term memory network for RUL prediction

# %%
# !pip install keras==2.4.3
# Out:
# Requirement already satisfied: keras==2.4.3 in /usr/local/lib/python3.7/dist-packages (2.4.3)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->keras==2.4.3) (1.15.0)

# %%
# !pip install tensorflow==2.3.1.
# Out:
# Requirement already satisfied: tensorflow==2.3.1. in /usr/local/lib/python3.7/dist-packages (2.3.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (1.43.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (0.12.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (1.18.5)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (3.17.3)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (2.7.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (1.13.3)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (0.3.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (2.10.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (0.37.1)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.1.) (1.1.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (4.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.1.) (3.1.1)

# %%
# !pip install keras_self_attention
# Out:
# Requirement already satisfied: keras_self_attention in /usr/local/lib/python3.7/dist-packages (0.51.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras_self_attention) (1.18.5)

# %%
import keras
import keras.backend as K
from keras.layers.core import Activation
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout, Conv1D
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras_self_attention
from sklearn import preprocessing

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D
from keras.layers.merge import concatenate
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.layers import LSTM 
from keras.layers import Attention,Lambda
from keras_self_attention import SeqSelfAttention
import pydot_ng as pydot
import pydotplus
import graphviz

# %% [markdown]
# os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

# %% [markdown]
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %% [markdown]
# ## Mount the dataset on a drive or specify path

# %%
# In the NASA dataset, there are four data subsets (FD001-4). 
# This function is developed to handle any of the data subsets.

# %%
def read_data(filename):

    """function to turn the dataset into dataframe with column headings"""

    train_df = pd.read_csv(
        "/content/sample_data/train_" + filename + ".txt", sep=" ", header=None
    )
    train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
    train_df.columns = [
        "id",
        "cycle",
        "setting1",
        "setting2",
        "setting3",
        "s1",
        "s2",
        "s3",
        "s4",
        "s5",
        "s6",
        "s7",
        "s8",
        "s9",
        "s10",
        "s11",
        "s12",
        "s13",
        "s14",
        "s15",
        "s16",
        "s17",
        "s18",
        "s19",
        "s20",
        "s21",
    ]

    train_df = train_df.sort_values(["id", "cycle"])

    test_df = pd.read_csv(
        "/content/sample_data/test_" + filename + ".txt", sep=" ", header=None
    )
    test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
    test_df.columns = [
        "id",
        "cycle",
        "setting1",
        "setting2",
        "setting3",
        "s1",
        "s2",
        "s3",
        "s4",
        "s5",
        "s6",
        "s7",
        "s8",
        "s9",
        "s10",
        "s11",
        "s12",
        "s13",
        "s14",
        "s15",
        "s16",
        "s17",
        "s18",
        "s19",
        "s20",
        "s21",
    ]

    truth_df = pd.read_csv(
        "/content/sample_data/RUL_" + filename + ".txt", sep=" ", header=None
    )
    truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)
    return train_df, test_df, truth_df

# %%
#Specify the data subset to use for training
filename= "FD001"

# %%
# Model can be trained using a set of time windows
# ranging from 20 to 120. Specify the window length

sequence_length = 50

# Not all columns in the dataset is used. Select useful signals in the dataset

sequence_cols = ["s" + str(i) for i in set(range(1, 22))] + [
    "setting1",
    "setting2",
    "setting3",
    "cycle_norm",
]

if filename == "FD001":
    cycle = 130
    sequence_cols = [
        x
        for x in sequence_cols
        if x not in ["s1", "s5", "s6", "s10", "s16", "s18", "s19", "setting3"]
    ]
elif filename == "FD003":
    cycle = 130
    sequence_cols = [
        x
        for x in sequence_cols
        if x not in ["s1", "s5", "s16", "s18", "s19", "setting3"]
    ]
else:
    cycle = 130
    sequence_cols = ["s" + str(i) for i in set(range(1, 22))] + [
        "setting1",
        "setting2",
        "setting3",
        "cycle_norm",
    ]

# %%
train_df, test_df, truth_df = read_data(filename)

# %%
train_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3  ...  s17   s18    s19    s20      s21
# 0   1      1   -0.0007   -0.0004     100.0  ...  392  2388  100.0  39.06  23.4190
# 1   1      2    0.0019   -0.0003     100.0  ...  392  2388  100.0  39.00  23.4236
# 2   1      3   -0.0043    0.0003     100.0  ...  390  2388  100.0  38.95  23.3442
# 3   1      4    0.0007    0.0000     100.0  ...  392  2388  100.0  38.88  23.3739
# 4   1      5   -0.0019   -0.0002     100.0  ...  393  2388  100.0  38.90  23.4044
#
# [5 rows x 26 columns]

# %%
test_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3  ...  s17   s18    s19    s20      s21
# 0   1      1    0.0023    0.0003     100.0  ...  392  2388  100.0  38.86  23.3735
# 1   1      2   -0.0027   -0.0003     100.0  ...  393  2388  100.0  39.02  23.3916
# 2   1      3    0.0003    0.0001     100.0  ...  393  2388  100.0  39.08  23.4166
# 3   1      4    0.0042    0.0000     100.0  ...  391  2388  100.0  39.00  23.3737
# 4   1      5    0.0014    0.0000     100.0  ...  390  2388  100.0  38.99  23.4130
#
# [5 rows x 26 columns]

# %%
#Preprocess the dataset

# %%
# These two functions preprocess the training and test dataset respectively

def train_data_prep(train_df):
      """
       A function to preprocess the training dataset for piece-wise RUL
       estimation
       
       Parameter:
         
         training dataframe (FD001-4)
        
       Returns:
         
         train_df, a preprocessed dataframe with column names
        and target variable.

      """
      rul = pd.DataFrame(train_df.groupby("id")["cycle"].max()).reset_index()
      rul.columns = ["id", "max"]
      train_df = train_df.merge(rul, on=["id"], how="left")
      train_df["RUL"] = train_df["max"] - train_df["cycle"]
      train_df.drop("max", axis=1, inplace=True)
      train_df["R_early"] = train_df["RUL"].apply(lambda x: cycle if x >= cycle else x)
      train_df = train_df.drop(["RUL"], axis=1)
      return train_df

def test_data_prep(test_df, truth_df):
    """
    A function to preprocess the test data subset for
     piece-wise RUL prediction
          
        Parameters:

          truth_df: the actual RUL
          test_df: the test data subset

        Returns:

          test_df: a preprocessed test dataset with piecewise RUL.
          """
    rul = pd.DataFrame(test_df.groupby("id")["cycle"].max()).reset_index()
    rul.columns = ["id", "max"]
    truth_df.columns = ["more"]
    truth_df["id"] = truth_df.index + 1
    truth_df["max"] = rul["max"] + truth_df["more"]
    truth_df.drop("more", axis=1, inplace=True)
    # generate RUL for test data
    test_df = test_df.merge(truth_df, on=["id"], how="left")
    test_df["RUL"] = test_df["max"] - test_df["cycle"]
    test_df.drop("max", axis=1, inplace=True)
    test_df["R_early"] = test_df["RUL"].apply(lambda x: cycle if x >= cycle else x)
    test_df = test_df.drop(["RUL"], axis=1)
    return test_df

# %%
train_df = train_data_prep(train_df)

# %%
train_df.head()
# Out:
#    id  cycle  setting1  setting2  ...    s19    s20      s21  R_early
# 0   1      1   -0.0007   -0.0004  ...  100.0  39.06  23.4190      130
# 1   1      2    0.0019   -0.0003  ...  100.0  39.00  23.4236      130
# 2   1      3   -0.0043    0.0003  ...  100.0  38.95  23.3442      130
# 3   1      4    0.0007    0.0000  ...  100.0  38.88  23.3739      130
# 4   1      5   -0.0019   -0.0002  ...  100.0  38.90  23.4044      130
#
# [5 rows x 27 columns]

# %%
test_df= test_data_prep(test_df, truth_df)

# %%
test_df.head()
# Out:
#    id  cycle  setting1  setting2  ...    s19    s20      s21  R_early
# 0   1      1    0.0023    0.0003  ...  100.0  38.86  23.3735      130
# 1   1      2   -0.0027   -0.0003  ...  100.0  39.02  23.3916      130
# 2   1      3    0.0003    0.0001  ...  100.0  39.08  23.4166      130
# 3   1      4    0.0042    0.0000  ...  100.0  39.00  23.3737      130
# 4   1      5    0.0014    0.0000  ...  100.0  38.99  23.4130      130
#
# [5 rows x 27 columns]

# %%
#Normalize the dataset

# %%
#This function normalizes the training and test dataset.
def train_test_scaler(train_data, test_data):

    """function to standardize the dataset"""

    train_data["cycle_norm"] = train_data["cycle"]
    cols_normalize = train_data.columns.difference(["id", "cycle", "R_early"])
    min_max_scaler = preprocessing.MinMaxScaler()
    norm_train_df = pd.DataFrame(
        min_max_scaler.fit_transform(train_data[cols_normalize]),
        columns=cols_normalize,
        index=train_data.index,
    )
    join_df = train_data[train_data.columns.difference(cols_normalize)].join(
        norm_train_df
    )
    train_df = join_df.reindex(columns=train_data.columns)

    # MinMax normalization (from 0 to 1)
    test_data["cycle_norm"] = test_data["cycle"]
    norm_test_df = pd.DataFrame(
        min_max_scaler.transform(test_data[cols_normalize]),
        columns=cols_normalize,
        index=test_data.index,
    )
    test_join_df = test_data[test_data.columns.difference(cols_normalize)].join(
        norm_test_df
    )
    test_df = test_join_df.reindex(columns=test_data.columns)
    test_df = test_df.reset_index(drop=True)
    return train_df, test_df

# %%
train_df, test_df = train_test_scaler(train_df, test_df)

# %%
#Generate and reshape the training and test dataset

# %%
#These functions reshape the training and test datasets in three dimension

def gen_sequence(id_df, seq_length, seq_cols):

    """
    sequence generator

    Parameters:

        id_df: Engine ID
        seq_length: Sequence length
        seq_cols: Sequence column

    """

    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]

    for start, stop in zip(
        range(0, num_elements - seq_length), range(seq_length, num_elements)
    ):
        yield data_matrix[start:stop, :]


def sequence_gen(train_data, sequence_length, sequence_cols):

    """
    training sequence generator.

    Returns:
        Generated sequence in the form
        [samples, time_steps, features]

    """
    seq_gen = (
        list(
            gen_sequence(
                train_data[train_data["id"] == id], sequence_length, sequence_cols
            )
        )
        for id in train_data["id"].unique()
    )
    # generate sequences and convert to numpy array
    seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
    return seq_array


# function to generate labels
def gen_labels(id_df, seq_length, label):
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    return data_matrix[seq_length:num_elements, :]


def label_generator(train_data, sequence_length, sequence_cols):
    """ generate labels """
    label_gen = [
        gen_labels(train_data[train_data["id"] == id], sequence_length, ["R_early"])
        for id in train_data["id"].unique()
    ]
    label_array = np.concatenate(label_gen).astype(np.float32)
    return label_array

# %%
#Specify training sample, training label
seq_array = sequence_gen(train_df, sequence_length, sequence_cols)
label_array = label_generator(train_df, sequence_length, ['R_early'])
print('Data Shape: ', seq_array.shape)
print('Label Shape: ', label_array.shape)
# Out:
# Data Shape:  (15631, 50, 17)
# Label Shape:  (15631, 1)

# %%
seq_array[0][:,2].reshape(-1,1).shape
# Out:
# (50, 1)

# %%
# Similarly, prepare the test data for model evaluation

# %%
# prepare test data for model evaluation
def test_data_eval(test_df, sequence_length, sequence_cols):

    """
    This function pick the last sequence for each
    engine in the test data for model evaluation

    """
    seq_array_test_last = [
        test_df[test_df["id"] == id][sequence_cols].values[-sequence_length:]
        for id in test_df["id"].unique()
        if len(test_df[test_df["id"] == id]) >= sequence_length
    ]
    seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)

    y_mask = [
        len(test_df[test_df["id"] == id]) >= sequence_length
        for id in test_df["id"].unique()
    ]
    label_array_test_last = test_df.groupby("id")["R_early"].nth(-1)[y_mask].values
    label_array_test_last = label_array_test_last.reshape(
        label_array_test_last.shape[0], 1
    ).astype(np.float32)
    return seq_array_test_last, label_array_test_last

# %%
#Specify test sample, test label
seq_array_test, label_array_test = test_data_eval(test_df, sequence_length, sequence_cols)
print("Data Shape: ", seq_array_test.shape)
print("Label Shape: ", label_array_test.shape)
# Out:
# Data Shape:  (93, 50, 17)
# Label Shape:  (93, 1)

# %%
#Specify number of timesteps, features, and output
nb_timesteps=seq_array.shape[1]
nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

# %%
#For conventional models, seq_array, will be used for training, and seq_array_test, will be used for testing
#However, for multihead models, reshape the training sample so that each head is used to learn different features in the training sample

# %%
training_sample_multihead = [seq_array[:,:,i].reshape((seq_array.shape[0],sequence_length,1)) for i in range(nb_features)]

# %%
test_sample_multihead = test_data = [seq_array_test[:,:,i].reshape((seq_array_test.shape[0],sequence_length,1)) for i in range(nb_features)]

# %%
# these are the evaluation metrics for the model
def k_score(y_true, y_pred):

    """score metric used for model evaluation"""

    d = y_pred - y_true
    return K.sum(K.exp(d[d >= 0] / 10) - 1) + K.sum(K.exp(-1 * d[d < 0] / 13) - 1)


def rmse(y_true, y_pred):

    """rmse metric used for model evaluation"""

    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
#Create attention_based Multihead CNLSTM
import tensorflow as tf

# %%
#Attention_based multihead CNLSTM
#This is my implemetation of the AMCNLSTM. Feel free to experiment with the architecture
in_layers = Input(shape=(sequence_length,nb_features))
#print(in_layers.shape)
out_layers = list()
for i in range(nb_features):
  inputs = Lambda(lambda x: x[:,:, i])(in_layers)
  #print(inputs.shape)
  #inputs=inputs.reshape(-1,1)
  #inputs=tf.reshape(inputs, [inputs.shape[0],inputs.shape[-1],1])
  inputs=tf.expand_dims(inputs,-1)
  #print(inputs.shape)
  rnn1 = Conv1D(filters=64,kernel_size=2,strides=1,padding="same",name="conv1d_1_"+str(i))(inputs)
  lr1= LeakyReLU()(rnn1)
  bn1= BatchNormalization()(lr1)
  rnn2 = Conv1D(filters=64,kernel_size=2,strides=1,padding="same",name="conv1d_2_"+str(i))(bn1)
  lr2= LeakyReLU()(rnn2)
  bn2= BatchNormalization()(lr2)
  rnn3 = LSTM(units=50, return_sequences=True,name='LSTM_1_'+str(i))(bn2)
  lr3= LeakyReLU()(rnn3)
  bn3= BatchNormalization()(lr3)
  att = SeqSelfAttention(name="selfattn_"+str(i),attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL, kernel_regularizer=keras.regularizers.l2(1e-4), bias_regularizer=keras.regularizers.l1(1e-4), attention_regularizer_weight=1e-4,attention_width=15)(bn3)
  pool1 = MaxPooling1D(pool_size=2)(att)
  flat = Flatten()(pool1)
  # store layers
  #in_layers.append(inputs)
  out_layers.append(flat)
# merge heads
merged = concatenate(out_layers)
# interpretation
dense1 = Dense(50, activation='relu')(merged)
outputs = Dense(nb_out)(dense1)
model = Model(inputs=in_layers, outputs=outputs)
optimizer = keras.optimizers.Adam(lr=3e-5)

model.compile(loss=keras.losses.Huber(),
              optimizer=optimizer,
              metrics=[rmse, k_score])
# Out:
# WARNING:tensorflow:Layer LSTM_1_0 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_4 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_5 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_7 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_8 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_12 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_13 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_14 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_15 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer LSTM_1_16 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
# Creat model checkpoint to save the best model performance
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath="/content/sample_data/" + filename + ".h5", save_best_only=True, verbose=1
)

# specify ealy_callback to stop training model if there's no improvement after 5 epochs
early_stopping = keras.callbacks.EarlyStopping(patience=5)

# Get the model summary
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50, 17)]     0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 50)           0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, 50, 1)]      0           lambda[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_1 (Tenso [(None, 50, 1)]      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_2 (Tenso [(None, 50, 1)]      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_3 (Tenso [(None, 50, 1)]      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_4 (Tenso [(None, 50, 1)]      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_5 (Tenso [(None, 50, 1)]      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_6 (Tenso [(None, 50, 1)]      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_7 (Tenso [(None, 50, 1)]      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_8 (Tenso [(None, 50, 1)]      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_9 (Tenso [(None, 50, 1)]      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_10 (Tens [(None, 50, 1)]      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_11 (Tens [(None, 50, 1)]      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_12 (Tens [(None, 50, 1)]      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_13 (Tens [(None, 50, 1)]      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_14 (Tens [(None, 50, 1)]      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_15 (Tens [(None, 50, 1)]      0           lambda_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_16 (Tens [(None, 50, 1)]      0           lambda_16[0][0]
# __________________________________________________________________________________________________
# conv1d_1_0 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# conv1d_1_1 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1_2 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_2[0][0]
# __________________________________________________________________________________________________
# conv1d_1_3 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_3[0][0]
# __________________________________________________________________________________________________
# conv1d_1_4 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_4[0][0]
# __________________________________________________________________________________________________
# conv1d_1_5 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_5[0][0]
# __________________________________________________________________________________________________
# conv1d_1_6 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_6[0][0]
# __________________________________________________________________________________________________
# conv1d_1_7 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_7[0][0]
# __________________________________________________________________________________________________
# conv1d_1_8 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_8[0][0]
# __________________________________________________________________________________________________
# conv1d_1_9 (Conv1D)             (None, 50, 64)       192         tf_op_layer_ExpandDims_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1_10 (Conv1D)            (None, 50, 64)       192         tf_op_layer_ExpandDims_10[0][0]
# __________________________________________________________________________________________________
# conv1d_1_11 (Conv1D)            (None, 50, 64)       192         tf_op_layer_ExpandDims_11[0][0]
# __________________________________________________________________________________________________
# conv1d_1_12 (Conv1D)            (None, 50, 64)       192         tf_op_layer_ExpandDims_12[0][0]
# __________________________________________________________________________________________________
# conv1d_1_13 (Conv1D)            (None, 50, 64)       192         tf_op_layer_ExpandDims_13[0][0]
# __________________________________________________________________________________________________
# conv1d_1_14 (Conv1D)            (None, 50, 64)       192         tf_op_layer_ExpandDims_14[0][0]
# __________________________________________________________________________________________________
# conv1d_1_15 (Conv1D)            (None, 50, 64)       192         tf_op_layer_ExpandDims_15[0][0]
# __________________________________________________________________________________________________
# conv1d_1_16 (Conv1D)            (None, 50, 64)       192         tf_op_layer_ExpandDims_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 50, 64)       0           conv1d_1_0[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 50, 64)       0           conv1d_1_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 50, 64)       0           conv1d_1_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 50, 64)       0           conv1d_1_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 50, 64)       0           conv1d_1_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 50, 64)       256         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 50, 64)       256         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 64)       256         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 64)       256         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 50, 64)       256         leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 64)       256         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 64)       256         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 50, 64)       256         leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 50, 64)       256         leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 50, 64)       256         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 50, 64)       256         leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 50, 64)       256         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 50, 64)       256         leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 50, 64)       256         leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 50, 64)       256         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 50, 64)       256         leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 50, 64)       256         leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# conv1d_2_0 (Conv1D)             (None, 50, 64)       8256        batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_2_1 (Conv1D)             (None, 50, 64)       8256        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2_2 (Conv1D)             (None, 50, 64)       8256        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv1d_2_3 (Conv1D)             (None, 50, 64)       8256        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_2_4 (Conv1D)             (None, 50, 64)       8256        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv1d_2_5 (Conv1D)             (None, 50, 64)       8256        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_2_6 (Conv1D)             (None, 50, 64)       8256        batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv1d_2_7 (Conv1D)             (None, 50, 64)       8256        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_2_8 (Conv1D)             (None, 50, 64)       8256        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_2_9 (Conv1D)             (None, 50, 64)       8256        batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_2_10 (Conv1D)            (None, 50, 64)       8256        batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_2_11 (Conv1D)            (None, 50, 64)       8256        batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_2_12 (Conv1D)            (None, 50, 64)       8256        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_2_13 (Conv1D)            (None, 50, 64)       8256        batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_2_14 (Conv1D)            (None, 50, 64)       8256        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_2_15 (Conv1D)            (None, 50, 64)       8256        batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_2_16 (Conv1D)            (None, 50, 64)       8256        batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 50, 64)       0           conv1d_2_0[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 50, 64)       0           conv1d_2_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 50, 64)       0           conv1d_2_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 50, 64)       0           conv1d_2_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50, 64)       256         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 50, 64)       256         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 64)       256         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 64)       256         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 64)       256         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 50, 64)       256         leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 50, 64)       256         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 50, 64)       256         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 50, 64)       256         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 50, 64)       256         leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 50, 64)       256         leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 50, 64)       256         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 50, 64)       256         leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 50, 64)       256         leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 50, 64)       256         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 50, 64)       256         leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 50, 64)       256         leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# LSTM_1_0 (LSTM)                 (None, 50, 50)       23000       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# LSTM_1_1 (LSTM)                 (None, 50, 50)       23000       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# LSTM_1_2 (LSTM)                 (None, 50, 50)       23000       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# LSTM_1_3 (LSTM)                 (None, 50, 50)       23000       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# LSTM_1_4 (LSTM)                 (None, 50, 50)       23000       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# LSTM_1_5 (LSTM)                 (None, 50, 50)       23000       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# LSTM_1_6 (LSTM)                 (None, 50, 50)       23000       batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# LSTM_1_7 (LSTM)                 (None, 50, 50)       23000       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# LSTM_1_8 (LSTM)                 (None, 50, 50)       23000       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# LSTM_1_9 (LSTM)                 (None, 50, 50)       23000       batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# LSTM_1_10 (LSTM)                (None, 50, 50)       23000       batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# LSTM_1_11 (LSTM)                (None, 50, 50)       23000       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# LSTM_1_12 (LSTM)                (None, 50, 50)       23000       batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# LSTM_1_13 (LSTM)                (None, 50, 50)       23000       batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# LSTM_1_14 (LSTM)                (None, 50, 50)       23000       batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# LSTM_1_15 (LSTM)                (None, 50, 50)       23000       batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# LSTM_1_16 (LSTM)                (None, 50, 50)       23000       batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 50, 50)       0           LSTM_1_0[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 50, 50)       0           LSTM_1_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 50, 50)       0           LSTM_1_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 50, 50)       0           LSTM_1_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 50)       200         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 50, 50)       200         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50)       200         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 50, 50)       200         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 50, 50)       200         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50)       200         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 50, 50)       200         leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 50, 50)       200         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 50, 50)       200         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 50, 50)       200         leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 50, 50)       200         leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 50, 50)       200         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50)       200         leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 50, 50)       200         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 50, 50)       200         leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 50, 50)       200         leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 50, 50)       200         leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# selfattn_0 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# selfattn_1 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# selfattn_2 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# selfattn_3 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# selfattn_4 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# selfattn_5 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# selfattn_6 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# selfattn_7 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# selfattn_8 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# selfattn_9 (SeqSelfAttention)   (None, 50, 50)       2501        batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# selfattn_10 (SeqSelfAttention)  (None, 50, 50)       2501        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# selfattn_11 (SeqSelfAttention)  (None, 50, 50)       2501        batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# selfattn_12 (SeqSelfAttention)  (None, 50, 50)       2501        batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# selfattn_13 (SeqSelfAttention)  (None, 50, 50)       2501        batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# selfattn_14 (SeqSelfAttention)  (None, 50, 50)       2501        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# selfattn_15 (SeqSelfAttention)  (None, 50, 50)       2501        batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# selfattn_16 (SeqSelfAttention)  (None, 50, 50)       2501        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 25, 50)       0           selfattn_0[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 25, 50)       0           selfattn_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 25, 50)       0           selfattn_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 25, 50)       0           selfattn_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 25, 50)       0           selfattn_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 25, 50)       0           selfattn_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 25, 50)       0           selfattn_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 25, 50)       0           selfattn_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 25, 50)       0           selfattn_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 25, 50)       0           selfattn_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 25, 50)       0           selfattn_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 25, 50)       0           selfattn_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 25, 50)       0           selfattn_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 25, 50)       0           selfattn_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 25, 50)       0           selfattn_14[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (None, 25, 50)       0           selfattn_15[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 25, 50)       0           selfattn_16[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1250)         0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1250)         0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1250)         0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1250)         0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 1250)         0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 1250)         0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 1250)         0           max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 1250)         0           max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 1250)         0           max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 1250)         0           max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 1250)         0           max_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 1250)         0           max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 1250)         0           max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 1250)         0           max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 1250)         0           max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 1250)         0           max_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# flatten_16 (Flatten)            (None, 1250)         0           max_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 21250)        0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  flatten_7[0][0]
#                                                                  flatten_8[0][0]
#                                                                  flatten_9[0][0]
#                                                                  flatten_10[0][0]
#                                                                  flatten_11[0][0]
#                                                                  flatten_12[0][0]
#                                                                  flatten_13[0][0]
#                                                                  flatten_14[0][0]
#                                                                  flatten_15[0][0]
#                                                                  flatten_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 50)           1062550     concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            51          dense[0][0]
# ==================================================================================================
# Total params: 1,651,838
# Trainable params: 1,645,786
# Non-trainable params: 6,052
# __________________________________________________________________________________________________

# %%
# Plot the model
#It can be seen here that the number of heads= number of features (columns) in the training sample
pydot.find_graphviz()
keras.utils.plot_model(model, show_shapes=True, to_file='AMCNLSTM.png',dpi=40)

# %%
print(seq_array.shape,label_array.shape)
# Out:
# (15631, 50, 17) (15631, 1)

# %%
#Train the multihead model
keras.backend.clear_session()

train_history=model.fit(seq_array, label_array, epochs=500,
        validation_split=0.2,callbacks=[early_stopping, model_checkpoint])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-6e6ac3e42c9e> in <module>()
#       3
#       4 train_history=model.fit(seq_array, label_array, epochs=500,
# ----> 5         validation_split=0.2,callbacks=[early_stopping, model_checkpoint])
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     807         max_queue_size=max_queue_size,
#     808         workers=workers,
# --> 809         use_multiprocessing=use_multiprocessing)
#     810
#     811   def evaluate(self,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     664         validation_steps=validation_steps,
#     665         validation_freq=validation_freq,
# --> 666         steps_name='steps_per_epoch')
#     667
#     668   def evaluate(self,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     187   # function we recompile the metrics based on the updated
#     188   # sample_weight_mode value.
# --> 189   f = _make_execution_function(model, mode)
#     190
#     191   # Prepare validation data. Hold references to the iterator and the input list
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_arrays.py in _make_execution_function(model, mode)
#     555   if model._distribution_strategy:
#     556     return distributed_training_utils._make_execution_function(model, mode)
# --> 557   return model._make_execution_function(mode)
#     558
#     559
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py in _make_execution_function(self, mode)
#    2074   def _make_execution_function(self, mode):
#    2075     if mode == ModeKeys.TRAIN:
# -> 2076       self._make_train_function()
#    2077       return self.train_function
#    2078     if mode == ModeKeys.TEST:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py in _make_train_function(self)
#    2006           # Training updates
#    2007           updates = self.optimizer.get_updates(
# -> 2008               params=self._collected_trainable_weights, loss=self.total_loss)
#    2009           # Unconditional updates
#    2010           updates += self.get_updates_for(None)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in get_updates(self, loss, params)
#     652         if g is not None and v.dtype != dtypes.resource
#     653     ])
# --> 654     return [self.apply_gradients(grads_and_vars)]
#     655
#     656   def _set_hyper(self, name, value):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     547           args=(grads_and_vars,),
#     548           kwargs={
# --> 549               "name": name,
#     550           })
#     551
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in merge_call(self, merge_fn, args, kwargs)
#    2713     merge_fn = autograph.tf_convert(
#    2714         merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 2715     return self._merge_call(merge_fn, args, kwargs)
#    2716
#    2717   def _merge_call(self, merge_fn, args, kwargs):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in _merge_call(self, merge_fn, args, kwargs)
#    2720         distribution_strategy_context._CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    2721     try:
# -> 2722       return merge_fn(self._strategy, *args, **kwargs)
#    2723     finally:
#    2724       _pop_per_thread_mode()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     273   def wrapper(*args, **kwargs):
#     274     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 275       return func(*args, **kwargs)
#     276
#     277   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _distributed_apply(self, distribution, grads_and_vars, name, apply_state)
#     631                               "update_" + var.op.name, skip_on_eager=True):
#     632             update_ops.extend(distribution.extended.update(
# --> 633                 var, apply_grad_to_update_var, args=(grad,), group=False))
#     634
#     635       any_symbolic = any(isinstance(i, ops.Operation) or
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    2298         fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2299     with self._container_strategy().scope():
# -> 2300       return self._update(var, fn, args, kwargs, group)
#    2301
#    2302   def _update(self, var, fn, args, kwargs, group):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in _update(self, var, fn, args, kwargs, group)
#    2953     # The implementations of _update() and _update_non_slot() are identical
#    2954     # except _update() passes `var` as the first argument to `fn()`.
# -> 2955     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#    2956
#    2957   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in _update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    2959     # once that value is used for something.
#    2960     with UpdateContext(colocate_with):
# -> 2961       result = fn(*args, **kwargs)
#    2962       if should_group:
#    2963         return result
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     273   def wrapper(*args, **kwargs):
#     274     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 275       return func(*args, **kwargs)
#     276
#     277   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_grad_to_update_var(var, grad)
#     606       if "apply_state" in self._dense_apply_args:
#     607         apply_kwargs["apply_state"] = apply_state
# --> 608       update_op = self._resource_apply_dense(grad, var, **apply_kwargs)
#     609       if var.constraint is not None:
#     610         with ops.control_dependencies([update_op]):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/adam.py in _resource_apply_dense(self, grad, var, apply_state)
#     183           coefficients['epsilon'],
#     184           grad,
# --> 185           use_locking=self._use_locking)
#     186     else:
#     187       vhat = self.get_slot(var, 'vhat')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/gen_training_ops.py in resource_apply_adam(var, m, v, beta1_power, beta2_power, lr, beta1, beta2, epsilon, grad, use_locking, use_nesterov, name)
#    1451                              beta2=beta2, epsilon=epsilon, grad=grad,
#    1452                              use_locking=use_locking,
# -> 1453                              use_nesterov=use_nesterov, name=name)
#    1454   return _op
#    1455 ResourceApplyAdam = tf_export("raw_ops.ResourceApplyAdam")(_ops.to_raw_op(resource_apply_adam))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     307     # Need to flatten all the arguments into a list.
#     308     # pylint: disable=protected-access
# --> 309     g = ops._get_graph_from_inputs(_Flatten(keywords.values()))
#     310     # pylint: enable=protected-access
#     311   except AssertionError as e:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _get_graph_from_inputs(op_input_list, graph)
#    6111         graph = getattr(graph_element, "graph", None)
#    6112       elif original_graph_element is not None:
# -> 6113         _assert_same_graph(original_graph_element, graph_element)
#    6114       elif graph_element.graph is not graph:
#    6115         raise ValueError("%s is not from the passed-in graph." % graph_element)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _assert_same_graph(original_item, item)
#    6046     raise ValueError(
#    6047         "%s must be from the same graph as %s (graphs are %s and %s)." %
# -> 6048         (item, original_item, graph, original_graph))
#    6049
#    6050
#
# ValueError: Tensor("training/Adam/conv1d_1_0_2/kernel/m:0", shape=(), dtype=resource) must be from the same graph as Tensor("conv1d_1_0_2/kernel:0", shape=(), dtype=resource) (graphs are <tensorflow.python.framework.ops.Graph object at 0x7fe89828a590> and <tensorflow.python.framework.ops.Graph object at 0x7fe8c0044990>).

# %%
from tensorflow.compat.v1.keras.backend import get_session
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()

# %%
# load the best checkpoint and evaluate on test set

# This function loads the best model
def load_model_from_disk(filename):

    """Functio to load the best model after training"""

    return load_model(
        "/content/sample_data/" + filename + ".h5",
        custom_objects={"rmse": rmse, "k_score": k_score,"SeqSelfAttention":SeqSelfAttention})

# %%
trained_model = load_model_from_disk(filename)

# %%
#Evaluate the model on test data
model_evaluation_res = trained_model.evaluate(
    seq_array_test, label_array_test,use_multiprocessing=True)

# %%
# Predict the degradation trend in test data
y_pred = trained_model.predict(seq_array_test)
#y_pred=np.squeeze(y_pred)

# %%
#plot the prediction vs the ground truth
def plot_result(y_true, y_pred, title=None):

    """ A function to plot the predicted RUL vs the target RUL for all engines"""

    fig = plt.figure(figsize = (3.5, 2.5))
    plt.grid(True,lw=0.1)
    plt.rcParams['axes.linewidth'] = 0.4  # set the value globally
    plt.plot(y_true, 'r', linewidth=0.5,linestyle='--')
    plt.plot(y_pred, 'k', linewidth=0.5)
    plt.title(title,fontsize=8)
    plt.xlabel('Time (Cycle)', fontsize=7)
    plt.xticks(fontsize=5)
    plt.ylabel('RUL', fontsize=7)
    plt.yticks(fontsize=5)
    plt.legend(['Actual RUL', 'Predicted RUL'],  loc='upper right', fontsize=5)
    plt.show()
    fig.savefig("/content/sample_data/"  + title + '.tiff', dpi=90, format='tiff', bbox_inches='tight')
    return fig

# %%
# View the results
plot_result(
    label_array_test, y_pred, title="Model prediction on " + filename + " test set"
)

# %%
# !pip install shap

# %%
training_sample_multihead[0].shape

# %%
test_sample_multihead[0].shape

# %%
import shap

random_ind = np.random.choice(seq_array.shape[0], 1000, replace = False)
data = seq_array[random_ind[0:1000]]

DE = shap.DeepExplainer(trained_model, data)
shap_val = DE.shap_values(seq_array_test)
shap_val = np.array(shap_val)
shap_val = np.reshape(shap_val, (shap_val.shape[1], shap_val.shape[2], shap_val.shape[3]))
shap_abs = np.abs(shap_val)
sum_0 = np.sum(shap_abs, axis = 0)

print(sum_0.shape)

# %%
shap_feat_importance = pd.DataFrame(columns=["features", "Importance"])
shap_feat_importance.features = sequence_cols
shap_feat_importance.Importance = sum_0[sequence_length-1]

fig, ax = plt.subplots(figsize = (8,10))
shap_feat_importance = shap_feat_importance.sort_values(by = "Importance")
shap_feat_importance.plot.barh(x = 'features', y = 'Importance', ax = ax)
ax.set_title('Shap Feature Importance of last cycle')
plt.show()

# %%
shap_feat_importance = pd.DataFrame(columns=["features", "Importance"])
shap_feat_importance.features = feats
shap_feat_importance.Importance = sum_0[0]

fig, ax = plt.subplots(figsize = (8,10))
shap_feat_importance = shap_feat_importance.sort_values(by = "Importance")
shap_feat_importance.plot.barh(x = 'features', y = 'Importance', ax = ax)
ax.set_title('Shap Feature Importance of first cycle')
plt.show()
